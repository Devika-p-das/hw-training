# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv(r'/home/user/Documents/zepto_2026_07_14.csv',  low_memory=False)

# %%
df.shape
# Out:
# (881077, 31)

# %%
df.isnull().sum()
# Out:
# crawl_date_and_time             0
# platform_name                   0
# store_id                        0
# store_name_location             0
# city                            0
# pin_code                        0
# unique_id                       0
# product_id_upc_ean              0
# department                      0
# category                        0
# sub_category                    0
# product_type               881077
# brand_name                      0
# product_name                    0
# product_description        881077
# product_grammage           136210
# package_type               881077
# net_quantity                    0
# variants                   873787
# item_mrp                        0
# item_selling_price              0
# out_of_stock_flag               0
# discount_flag                   0
# product_price                   0
# unit_price                 881077
# promo_offer_description         0
# promo_offer_price               0
# discount_in_percent             0
# stock_count                     0
# product_url                     0
# product_image_urls         881077
# dtype: int64

# %%
df.nunique()
# Out:
# crawl_date_and_time        15439
# platform_name                  1
# store_id                     310
# store_name_location          292
# city                           6
# pin_code                     136
# unique_id                   8824
# product_id_upc_ean          8613
# department                    10
# category                      24
# sub_category                 159
# product_type                   0
# brand_name                  1222
# product_name                8151
# product_description            0
# product_grammage             749
# package_type                   0
# net_quantity                1337
# variants                     145
# item_mrp                     993
# item_selling_price          1726
# out_of_stock_flag              2
# discount_flag                  2
# product_price               1726
# unit_price                     0
# promo_offer_description     1197
# promo_offer_price           1726
# discount_in_percent           91
# stock_count                   54
# product_url                 8825
# product_image_urls             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.unique_id.duplicated().sum()
