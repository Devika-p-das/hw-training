# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option("display.max_colwidth", None)

# %%
df= pd.read_csv(r'/home/user/Documents/zepto_2026_07_22.csv',  low_memory=False)

# %%
summary = (
    df[df["city"] == "Delhi"]
      .groupby(["category", "sub_category"])
      .size()
      .reset_index(name="product_count")
      .sort_values("product_count", ascending=True)
)

summary
# Out:
#                       category                sub_category  product_count
# 88                   Jewellery                        Sets              1
# 153                 Zepto Cafe                     Italian              1
# 149                 Zepto Cafe                       Asian              1
# 97   Masala, Dry Fruits & More            Powders & Pastes              2
# 155                 Zepto Cafe                       Sides              2
# 150                 Zepto Cafe                      Bakery              3
# 154                 Zepto Cafe                  Sandwiches              4
# 126         Stationery & Books              Crafts & Hobby             16
# 152                 Zepto Cafe                     Healthy             48
# 156                 Zepto Cafe                      Snacks             49
# 113          Pharma & Wellness                    Ayurveda             58
# 54         Dairy, Bread & Eggs               Indian Breads             61
# 79                   Hair Care    Hair Tools & Accessories             62
# 115          Pharma & Wellness         Vitamin Supplements             77
# 73                 Frozen Food                  Veg Snacks             97
# 65            Feminine Hygiene             Personal Safety            101
# 114          Pharma & Wellness  Rehydration & Electrolytes            102
# 112              Packaged Food                Ready To Eat            244
# 11                   Baby Care                   Baby Gear            261
# 15                   Baby Care                 Baby Safety            263
# 18                   Baby Care             Infant Clothing            324
# 157                 Zepto Cafe                Tea & Coffee            415
# 63            Feminine Hygiene          Period Pain Relief            428
# 144              Toys & Sports         Musical Accessories            481
# 145              Toys & Sports         Musical Instruments            522
# 68            Feminine Hygiene              Toilet Hygiene            529
# 106              Packaged Food         Baby & Toddler Food            632
# 136              Toys & Sports              Action Figures            635
# 19                   Baby Care                    Mom Care            715
# 148              Toys & Sports                     Toddler            801
# 59    Electronics & Appliances                    Grooming            817
# 151                 Zepto Cafe              Cold Beverages            879
# 143              Toys & Sports   Electronic Toys & Vehicle            890
# 138              Toys & Sports                 Art & Craft            921
# 116                   Skincare                   Body Care            922
# 92             Makeup & Beauty                     Gifting            962
# 7                    Baby Care          Baby & Mom Gifting            970
# 122                   Skincare            Hand & Feet Care            971
# 141              Toys & Sports             Doll & Play Set           1002
# 137              Toys & Sports   Activities & Outdoor Toys           1046
# 21                 Bath & Body                     Gifting           1048
# 139              Toys & Sports            Blocks & Puzzles           1094
# 10                   Baby Care                Baby Feeding           1106
# 20                 Bath & Body            Bath Accessories           1179
# 61            Feminine Hygiene               Intimate Care           1217
# 62            Feminine Hygiene                Panty Liners           1235
# 67            Feminine Hygiene                     Tampons           1272
# 12                   Baby Care                 Baby Health           1292
# 125                   Skincare              Toners & Mists           1292
# 108              Packaged Food                 Infant Food           1335
# 91             Makeup & Beauty                 Face Makeup           1340
# 146              Toys & Sports                   Soft Toys           1363
# 124                   Skincare                    Sun Care           1375
# 94             Makeup & Beauty                       Nails           1411
# 140              Toys & Sports          Card & Board Games           1457
# 13                   Baby Care                Baby Hygiene           1511
# 78                   Hair Care                Hair Styling           1666
# 90             Makeup & Beauty                  Eye Makeup           1712
# 17                   Baby Care                  Baby Wipes           1743
# 3  1, Dwarka Goyla Dairy Rd, Near Goyla More, Deenpur, Surya Vihar, Najafgarh, New Delhi, Delhi, 110043, India
# 4  1, Dwarka Goyla Dairy Rd, Near Goyla More, Deenpur, Surya Vihar, Najafgarh, New Delhi, Delhi, 110043, India
#
#     city  pin_code                             unique_id  \
# 0  Delhi    110043  08aa72b7-cac2-4cbb-84d9-525c812f19fa
# 1  Delhi    110043  02f06d00-5bfc-4574-9fe3-d96d443da0f8
# 2  Delhi    110043  e885d51e-6d37-47dd-9b02-42812c8f755e
# 3  Delhi    110043  1f2ac706-4277-40fa-928b-18980ec09289
# 4  Delhi    110043  ada057ef-353d-4fa5-a187-a34e5daf0864
#
#                      product_id_upc_ean        department  \
# 0  920e3ebd-5c66-4e51-9795-d48baf63ff1c  Atta, Rice & Dal
# 1  041ba1d7-0309-4533-8acd-33c18dfa2bd6  Atta, Rice & Dal
# 2  920e3ebd-5c66-4e51-9795-d48baf63ff1c  Atta, Rice & Dal
# 3  cf8a682e-43c4-49f3-81d0-3588c4baaf47  Atta, Rice & Dal
# 4  20c928c1-3a78-4d00-9177-dc90f72223d2  Atta, Rice & Dal
#
#                  category sub_category  product_type  brand_name  \
# 0  Atta, Rice, Oil & Dals         Atta           NaN  Aashirvaad
# 1  Atta, Rice, Oil & Dals         Atta           NaN  Daily Good
# 2  Atta, Rice, Oil & Dals         Atta           NaN  Aashirvaad
# 3  Atta, Rice, Oil & Dals         Atta           NaN     Pansari
# 4  Atta, Rice, Oil & Dals         Atta           NaN   Pillsbury
#
#                                         product_name  product_description  \
# 0  Aashirvaad Shudh Chakki Atta | Pure Atta 0% Maida                  NaN
# 1                            Whole Wheat Chakki Atta                  NaN
# 2  Aashirvaad Shudh Chakki Atta | Pure Atta 0% Maida                  NaN
# 3    Pansari Chakki Fresh Atta | 100% Atta, 0% Maida                  NaN
# 4                        Pillsbury Chakki Fresh Atta                  NaN
#
#   product_grammage  package_type    net_quantity variants  item_mrp  \
# 0            10 kg           NaN  1 pack (10 kg)      NaN     489.0
# 1            10 kg           NaN  1 pack (10 kg)      NaN     560.0
# 2             5 kg           NaN   1 pack (5 kg)      NaN     262.0
# 3            10 kg           NaN  1 pack (10 kg)      NaN     492.0
# 4            10 kg           NaN  1 pack (10 kg)      NaN     495.0
#
#    item_selling_price out_of_stock_flag discount_flag  product_price  \
# 0               449.0                No           Yes          449.0
# 1               381.0                No           Yes          381.0
# 2               238.0                No           Yes          238.0
# 3               397.0                No           Yes          397.0
# 4               399.0                No           Yes          399.0
#
#    unit_price promo_offer_description  promo_offer_price  discount_in_percent  \
# 0         NaN                 ₹40 OFF              449.0                    8
# 1         NaN                ₹179 OFF              381.0                   31
# 2         NaN                 ₹24 OFF              238.0                    9
# 3         NaN                 ₹95 OFF              397.0                   19
# 4         NaN                 ₹96 OFF              399.0                   19
#
#    stock_count  \
# 0            2
# 1            6
# 2            2
# 3            4
# 4            2
#
#                                                                                                          product_url  \
# 0  https://www.zepto.com/pn/aashirvaad-shudh-chakki-atta-pure-atta-0-maida/pvid/08aa72b7-cac2-4cbb-84d9-525c812f19fa
# 1                         https://www.zepto.com/pn/whole-wheat-chakki-atta/pvid/02f06d00-5bfc-4574-9fe3-d96d443da0f8
# 2  https://www.zepto.com/pn/aashirvaad-shudh-chakki-atta-pure-atta-0-maida/pvid/e885d51e-6d37-47dd-9b02-42812c8f755e
# 3      https://www.zepto.com/pn/pansari-chakki-fresh-atta-100-atta-0-maida/pvid/1f2ac706-4277-40fa-928b-18980ec09289
# 4                     https://www.zepto.com/pn/pillsbury-chakki-fresh-atta/pvid/ada057ef-353d-4fa5-a187-a34e5daf0864
#
#    product_image_urls
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df.shape
# Out:
# (443539, 31)

# %%
df.isnull().sum()
# Out:
# crawl_date_and_time             0
# platform_name                   0
# store_id                        0
# store_name_location             0
# city                            0
# pin_code                        0
# unique_id                       0
# product_id_upc_ean              0
# department                      0
# category                        0
# sub_category                    0
# product_type               443539
# brand_name                      0
# product_name                    0
# product_description        443539
# product_grammage            67591
# package_type               443539
# net_quantity                    1
# variants                   435208
# item_mrp                        0
# item_selling_price              0
# out_of_stock_flag               0
# discount_flag                   0
# product_price                   0
# unit_price                 443539
# promo_offer_description         0
# promo_offer_price               0
# discount_in_percent             0
# stock_count                     0
# product_url                     0
# product_image_urls         443539
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# crawl_date_and_time        13180
# platform_name                  1
# store_id                     159
# store_name_location          148
# city                           2
# pin_code                      79
# unique_id                   7229
# product_id_upc_ean          7066
# department                    10
# category                      25
# sub_category                 158
# product_type                   0
# brand_name                  1099
# product_name                6734
# product_description            0
# product_grammage             659
# package_type                   0
# net_quantity                1128
# variants                     142
# item_mrp                     879
# item_selling_price          1609
# out_of_stock_flag              2
# discount_flag                  2
# product_price               1609
# unit_price                     0
# promo_offer_description     1074
# promo_offer_price           1609
# discount_in_percent           91
# stock_count                   51
# product_url                 7231
# product_image_urls             0
# dtype: int64

# %%
df.city.value_counts()
# Out:
# city
# Delhi      342191
# Gurgaon    101348
# Name: count, dtype: int64

# %%
df[df['net_quantity'].isna()]
# Out:
#         crawl_date_and_time platform_name  \
# 388211  2026-07-22 13:43:17         zepto
#
#                                     store_id  \
# 388211  b6ac55e9-9d60-4ea1-86b8-fe554ea1490c
#
#                                                                                                store_name_location  \
# 388211  528/1, Shitala Mata Mandir Marg, Sheetla Colony Phase 2, Sheetala Colony, Gurugram, Haryana, 122017, India
#
#            city  pin_code                             unique_id  \
# 388211  Gurgaon    122017  f44d5eaf-082b-4424-be02-e0dd71beaf64
#
#                           product_id_upc_ean         department  \
# 388211  e80c7713-f499-4f36-bad3-70745079d84a  Organic & Premium
#
#              category   sub_category  product_type brand_name  \
# 388211  Packaged Food  Ready To Cook           NaN      Heinz
#
#               product_name  product_description product_grammage  \
# 388211  Heinz Beaked Beans                  NaN              NaN
#
#         package_type net_quantity variants  item_mrp  item_selling_price  \
# 388211           NaN          NaN      NaN     199.0               178.0
#
#        out_of_stock_flag discount_flag  product_price  unit_price  \
# 388211                No           Yes          178.0         NaN
#
#        promo_offer_description  promo_offer_price  discount_in_percent  \
# 388211                 ₹21 OFF              178.0                   10
#
#         stock_count  \
# 388211            2
#
#                                                                                   product_url  \
# 388211  https://www.zepto.com/pn/heinz-beaked-beans/pvid/f44d5eaf-082b-4424-be02-e0dd71beaf64
#
#         product_image_urls
# 388211                 NaN

# %%
import pandas as pd

# Missing product_grammage
grammage_missing = (
    df["product_grammage"].isna() |
    (df["product_grammage"].astype(str).str.strip() == "")
)

# net_quantity contains text inside parentheses
netqty_with_brackets = (
    df["net_quantity"]
      .fillna("")
      .str.contains(r"\(.+\)", regex=True)
)

issues = df[grammage_missing & netqty_with_brackets]

print("Rows found:", len(issues))

issues[[
    "unique_id",
    "product_name",
    "net_quantity",
    "product_grammage"
]]
# Out:
# Rows found: 0
# Empty DataFrame
# Columns: [unique_id, product_name, net_quantity, product_grammage]
# Index: []

# %%
import pandas as pd

# Missing product_grammage
grammage_missing = (
    df["product_grammage"].isna() |
    (df["product_grammage"].astype(str).str.strip() == "")
)

# net_quantity contains a measurement inside parentheses
pattern = r"\(\s*[\d.,]+\s*(g|kg|mg|ml|l)\s*(?:or\s*[\d.,]+\s*(g|kg|mg|ml|l))?(?:\s*\+\s*[\d.,]+\s*(g|kg|mg|ml|l))*\s*\)"

mask = df["net_quantity"].fillna("").str.contains(
    pattern,
    case=False,
    regex=True,
    na=False
)

issues = df[grammage_missing & mask]

print("Rows found:", len(issues))

issues[[
    "unique_id",
    "product_name",
    "net_quantity",
    "product_grammage"
]]
# Out:
# /tmp/ipykernel_18107/5463894.py:12: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = df["net_quantity"].fillna("").str.contains(
# Rows found: 0
# Empty DataFrame
# Columns: [unique_id, product_name, net_quantity, product_grammage]
# Index: []

# %%
city_department = pd.crosstab(df["city"], df["department"])

city_department
# Out:
# department  Atta, Rice & Dal  Baby Care  Bakery & Biscuits  \
# city
# Delhi                  15457      34228              29217
# Gurgaon                 4225      12546               8124
#
# department  Beauty & Cosmetics  Cold Drinks & Juices  Dairy & Breakfast  \
# city
# Delhi                    48036                 35101              44988
# Gurgaon                  14988                 10024              12940
#
# department  Munchies  Organic & Premium  Personal Care  Sweet Tooth
# city
# Delhi          19289              41038          46631        28206
# Gurgaon         5239              11061          14050         8151

# %%
### city wise category distribution
city_category = pd.crosstab(df["city"], df["category"])

# Cities where any category is missing
missing_categories = city_category[city_category.eq(0).any(axis=1)]

missing_categories
# Out:
# category  Atta, Rice, Oil & Dals  Baby Care  Bath & Body  Biscuits  \
# city
# Gurgaon                     6493       5849         6377      5518
#
# category  Breakfast & Sauces  Cold Drinks & Juices  Dairy, Bread & Eggs  \
# city
# Gurgaon                 4450                  6673                 8517
#
# category  Electronics & Appliances  Feminine Hygiene  Fragrances & Grooming  \
# city
# Gurgaon                        411              3293                   2635
#
# category  Frozen Food  Hair Care  Ice Creams & More  Jewellery  \
# city
# Gurgaon           552       4266               6424          0
#
# category  Makeup & Beauty  Masala, Dry Fruits & More  Munchies  Packaged Food  \
# city
# Gurgaon              3085                       3373      5973           4510
#
# category  Pharma & Wellness  Skincare  Stationery & Books  Sweet Cravings  \
# city
# Gurgaon                  81      9006                   9            4593
#
# category  Tea, Coffee & More  Toys & Sports  Zepto Cafe
# city
# Gurgaon                 3349           5859          52

# %%
dept_category = (
    df.groupby("department")["category"]
    .apply(lambda x: sorted(x.unique()))
    .reset_index()
)

dept_category
# Out:
#              department  \
# 0      Atta, Rice & Dal
# 1             Baby Care
# 2     Bakery & Biscuits
# 3    Beauty & Cosmetics
# 4  Cold Drinks & Juices
# 5     Dairy & Breakfast
# 6              Munchies
# 7     Organic & Premium
# 8         Personal Care
# 9           Sweet Tooth
#
#                                                                                                                                                      category
# 0                                                                                                                                    [Atta, Rice, Oil & Dals]
# 1                                                                            [Baby Care, Packaged Food, Pharma & Wellness, Stationery & Books, Toys & Sports]
# 2                                                                                              [Biscuits, Dairy, Bread & Eggs, Packaged Food, Sweet Cravings]
# 3                                                                                               [Fragrances & Grooming, Hair Care, Makeup & Beauty, Skincare]
# 4                            [Cold Drinks & Juices, Dairy, Bread & Eggs, Ice Creams & More, Packaged Food, Pharma & Wellness, Tea, Coffee & More, Zepto Cafe]
# 5                                                                             [Breakfast & Sauces, Dairy, Bread & Eggs, Frozen Food, Munchies, Packaged Food]
# 6                                                                                                        [Masala, Dry Fruits & More, Munchies, Packaged Food]
# 7  [Atta, Rice, Oil & Dals, Biscuits, Breakfast & Sauces, Masala, Dry Fruits & More, Munchies, Packaged Food, Sweet Cravings, Tea, Coffee & More, Zepto Cafe]
# 8                                                       [Baby Care, Bath & Body, Electronics & Appliances, Feminine Hygiene, Fragrances & Grooming, Skincare]
# 9     [Bath & Body, Biscuits, Dairy, Bread & Eggs, Fragrances & Grooming, Frozen Food, Ice Creams & More, Jewellery, Munchies, Packaged Food, Sweet Cravings]

# %%
master = df[["department", "category"]].drop_duplicates()
city_stock = (
    df.groupby("city")["out_of_stock_flag"]
    .value_counts()
    .unstack(fill_value=0)
)

city_stock["Total"] = city_stock.sum(axis=1)
city_stock["Out_of_stock_%"] = (
    city_stock["Yes"] / city_stock["Total"] * 100
).round(2)

city_stock.sort_values("Out_of_stock_%", ascending=False)
# Out:
# out_of_stock_flag      No    Yes   Total  Out_of_stock_%
# city
# Delhi              276779  65412  342191           19.12
# Gurgaon             83977  17371  101348           17.14

# %%
dept_stock = (
    df.groupby("department")["out_of_stock_flag"]
    .value_counts()
    .unstack(fill_value=0)
)

dept_stock["Total"] = dept_stock.sum(axis=1)
dept_stock["Out_of_stock_%"] = (
    dept_stock["Yes"] / dept_stock["Total"] * 100
).round(2)

dept_stock.sort_values("Out_of_stock_%", ascending=False)
# Out:
# out_of_stock_flag        No    Yes  Total  Out_of_stock_%
# department
# Baby Care             35544  11230  46774           24.01
# Personal Care         47408  13273  60681           21.87
# Beauty & Cosmetics    50339  12685  63024           20.13
# Cold Drinks & Juices  36391   8734  45125           19.36
# Dairy & Breakfast     47170  10758  57928           18.57
# Bakery & Biscuits     30646   6695  37341           17.93
# Sweet Tooth           29853   6504  36357           17.89
# Organic & Premium     44709   7390  52099           14.18
# Atta, Rice & Dal      16967   2715  19682           13.79
# Munchies              21729   2799  24528           11.41

# %%
cat_stock = (
    df.groupby("category")["out_of_stock_flag"]
    .value_counts()
    .unstack(fill_value=0)
)

cat_stock["Total"] = cat_stock.sum(axis=1)
cat_stock["Out_of_stock_%"] = (
    cat_stock["Yes"] / cat_stock["Total"] * 100
).round(2)

cat_stock.sort_values("Out_of_stock_%", ascending=False)
# Out:
# out_of_stock_flag             No   Yes  Total  Out_of_stock_%
# category
# Zepto Cafe                   664   790   1454           54.33
# Pharma & Wellness            206   112    318           35.22
# Electronics & Appliances     817   411   1228           33.47
# Makeup & Beauty             9998  3700  13698           27.01
# Fragrances & Grooming       8049  2937  10986           26.73
# Baby Care                  17947  6507  24454           26.61
# Dairy, Bread & Eggs        29020  8048  37068           21.71
# Feminine Hygiene           12590  3383  15973           21.18
# Skincare                   30048  7520  37568           20.02
# Toys & Sports              16155  4024  20179           19.94
# Biscuits                   20450  4701  25151           18.69
# Cold Drinks & Juices       24236  5530  29766           18.58
# Bath & Body                21994  4844  26838           18.05
# Sweet Cravings             17730  3723  21453           17.35
# Ice Creams & More          23557  4920  28477           17.28
# Hair Care                  14176  2874  17050           16.86
# Packaged Food              15774  3062  18836           16.26
# Atta, Rice, Oil & Dals     25508  4746  30254           15.69
# Munchies                   23636  4268  27904           15.30
# Tea, Coffee & More         12976  1983  14959           13.26
# Masala, Dry Fruits & More  14037  2029  16066           12.63
# Breakfast & Sauces         17924  2286  20210           11.31
# Frozen Food                 3239   384   3623           10.60
# Stationery & Books            24     1     25            4.00
# Jewellery                      1     0      1            0.00

# %%
store_oos = (
    df.pivot_table(
        index=["city", "store_id"],
        columns="out_of_stock_flag",
        aggfunc="size",
        fill_value=0
    )
    .reset_index()
)

# Ensure both columns exist
for col in ["Yes", "No"]:
    if col not in store_oos.columns:
        store_oos[col] = 0

store_oos["Total"] = store_oos["Yes"] + store_oos["No"]
store_oos["Out_of_stock_%"] = (
    store_oos["Yes"] / store_oos["Total"] * 100
).round(2)

store_oos = store_oos.sort_values(
    "Out_of_stock_%",
    ascending=False
)

store_oos
# Out:
# out_of_stock_flag     city                              store_id    No   Yes  \
# 143                Gurgaon  9fd9b34c-0ffe-4180-adde-ba6fd267fb50     0     1
# 114                  Delhi  f2818431-48b5-4b57-9ec5-02e8eef7bc92   926   702
# 16                   Delhi  261b9c45-eb5b-4398-be1c-909ccde6f629  1922  1376
# 139                Gurgaon  90f2f25e-b21f-4999-957f-a96a81f01dfb  2170  1485
# 40                   Delhi  4b54927e-5c54-4564-8c9f-1e518e6488e3  2160  1408
# 109                  Delhi  ead42923-cfd0-4a7d-bb71-b879631773f1  1879  1181
# 51                  3115           15.38
# 145                 1622           15.35
# 142                 3087           15.32
# 36                  2958           14.91
# 19                  2779           14.90
# 124                 3109           14.73
# 141                 3193           14.66
# 149                 1646           14.58
# 88                  3450           14.52
# 41                  3169           14.45
# 17                  3186           14.31
# 6                   3153           14.30
# 14                  3011           14.28
# 45                  3137           14.25
# 35                  3094           14.22
# 38                  3192           14.19
# 78                  3132           14.14
# 122                 1486           14.13
# 71                  3237           14.12
# 26                  3341           14.01
# 18                  1580           13.99
# 72                  3248           13.85
# 94                  3207           13.69
# 52                  3050           13.67
# 127                 1560           13.46
# 140                   60           13.33
# 113                 3165           13.02
# 13                  1460           13.01
# 11                  3031           13.00
# 1                   2720           12.94
# 101                 3133           12.89
# 69                  2900           12.79
# 27                  2859           12.70
# 43                  3082           12.43
# 147                 2924           12.41
# 134                 3031           12.34
# 28                  3134           12.32
# 79                  3058           12.26
# 129                 3164           12.23
# 91                  3046           12.21
# 5                   2993           12.16
# 58                  2887           11.85
# 68                  1246           11.64
# 9                   2946           11.58
# 152                 3179           11.45
# 133                 3119           11.29
# 131                 3046           11.29
# 31                  2932           11.26
# 123                 3191           11.25
# 49                  3067           11.02
# 100                 2940           11.02
# 22                  3202           10.99
# 150                 3123           10.89
# 110                 3064           10.87
# 53                  3221           10.74
# 144                 2789           10.72
# 3                   2899           10.62
# 48                  3280           10.61
# 97                  2914           10.50
# 42                  2895            9.78
# 37                  2910            9.31
# 10                  1578            9.06
# 103                 2964            9.04
# 83                  2916            8.98
# 154                 1479            8.86
# 135                 2800            8.50
# 87                  3200            8.09
# 156                 1050            8.00
# 85                  2847            7.97
# 63                  2912            7.49
# 62                  2947            6.99
# 75                  2835            6.31

# %%
store_id = "9fd9b34c-0ffe-4180-adde-ba6fd267fb50"

df[df["store_id"] == store_id]
# Out:
#         crawl_date_and_time platform_name  \
# 407892  2026-07-22 13:54:57         zepto
#
#                                     store_id  \
# 407892  9fd9b34c-0ffe-4180-adde-ba6fd267fb50
#
#                                                                                                                                       store_name_location  \
# 407892  Omi Tuition Classes/coaching Centre(otc), Near Sangam Sweet Shop, Near Chauma, Chauma Village, Sector 1, Mahzid, Gurugram, Haryana, 122017, India
#
#            city  pin_code                             unique_id  \
# 407892  Gurgaon    122017  e7beef17-2cdb-427a-859c-68fca8c4187c
#
#                           product_id_upc_ean department       category  \
# 407892  3f420b5b-21ed-4344-ba73-9417d3ad5d7a  Baby Care  Toys & Sports
#
#        sub_category  product_type brand_name  \
# 407892    Soft Toys           NaN     Fablue
#
#                                                                            product_name  \
# 407892  Fablue Penguin Plush & Soft Toy For Boys Girls And Kids | Black & White - 17 cm
#
#         product_description product_grammage  package_type net_quantity  \
# 407892                  NaN              NaN           NaN         1 pc
#
#        variants  item_mrp  item_selling_price out_of_stock_flag discount_flag  \
# 407892      NaN     499.0               497.0               Yes            No
#
#         product_price  unit_price promo_offer_description  promo_offer_price  \
# 407892          497.0         NaN                  ₹2 OFF              497.0
#
#         discount_in_percent  stock_count  \
# 407892                    0            0
#
#                                                                                                                                        product_url  \
# 407892  https://www.zepto.com/pn/fablue-penguin-plush-soft-toy-for-boys-girls-and-kids-black-white-17-cm/pvid/e7beef17-2cdb-427a-859c-68fca8c4187c
#
#         product_image_urls
# 407892                 NaN

# %%
import pandas as pd

# Ensure stock_count is numeric
df["stock_count"] = pd.to_numeric(df["stock_count"], errors="coerce")

# Normalize out_of_stock_flag
flag = df["out_of_stock_flag"].astype(str).str.strip().str.lower()

# 1. out_of_stock_flag = Yes, but stock_count > 0
yes_stock_gt0 = df[
    (flag == "yes") &
    (df["stock_count"] > 0)
]

print(f"Rows with out_of_stock_flag='Yes' but stock_count > 0: {len(yes_stock_gt0)}")
print(yes_stock_gt0[["unique_id", "product_name", "store_id", "stock_count", "out_of_stock_flag"]])

# 2. out_of_stock_flag = No, but stock_count = 0
no_stock_0 = df[
    (flag == "no") &
    (df["stock_count"] == 0)
]

print(f"\nRows with out_of_stock_flag='No' but stock_count = 0: {len(no_stock_0)}")
print(no_stock_0[["unique_id", "product_name", "store_id", "stock_count", "out_of_stock_flag"]])
# Out:
# Rows with out_of_stock_flag='Yes' but stock_count > 0: 0
# Empty DataFrame
# Columns: [unique_id, product_name, store_id, stock_count, out_of_stock_flag]
# Index: []
#
# Rows with out_of_stock_flag='No' but stock_count = 0: 0
# Empty DataFrame
# Columns: [unique_id, product_name, store_id, stock_count, out_of_stock_flag]
# Index: []

# %%
import pandas as pd

# Convert price columns to numeric
price_cols = [
    "item_mrp",
    "item_selling_price",
    "discount_in_percent"
]

for col in price_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Normalize discount flag
flag = df["discount_flag"].astype(str).str.strip().str.lower()

# 1. Selling Price > MRP
selling_gt_mrp = df[df["item_selling_price"] > df["item_mrp"]]

print(f"1. Selling Price > MRP : {len(selling_gt_mrp)} rows")
print(selling_gt_mrp[[
    "unique_id",
    "product_name",
    "item_mrp",
    "item_selling_price"
]])

# 2. Discount Flag = Yes but MRP == Selling Price
discount_no_difference = df[
    (flag == "yes") &
    (df["item_mrp"] == df["item_selling_price"])
]

print(f"\n2. Discount Flag = Yes but MRP == Selling Price : {len(discount_no_difference)} rows")
print(discount_no_difference[[
    "unique_id",
    "product_name",
    "item_mrp",
    "item_selling_price",
    "discount_flag"
]])

# 3. Discount % > 100
discount_gt_100 = df[df["discount_in_percent"] > 100]

print(f"\n3. Discount % > 100 : {len(discount_gt_100)} rows")
print(discount_gt_100[[
    "unique_id",
    "product_name",
    "item_mrp",
    "item_selling_price",
    "discount_in_percent"
]])
# Out:
# 1. Selling Price > MRP : 0 rows
# Empty DataFrame
# Columns: [unique_id, product_name, item_mrp, item_selling_price]
# Index: []
#
# 2. Discount Flag = Yes but MRP == Selling Price : 0 rows
# Empty DataFrame
# Columns: [unique_id, product_name, item_mrp, item_selling_price, discount_flag]
# Index: []
#
# 3. Discount % > 100 : 0 rows
# Empty DataFrame
# Columns: [unique_id, product_name, item_mrp, item_selling_price, discount_in_percent]
# Index: []

# %%
import re

# Normalize brand names
df["brand_norm"] = (
    df["brand_name"]
    .fillna("")
    .str.lower()
    .str.replace(r"[^a-z0-9]", "", regex=True)   # remove spaces, ', -, &, etc.
)

# Find brands that become the same after normalization
brand_issue = (
    df.groupby("brand_norm")
    .agg(
        variant_count=("brand_name", "nunique"),
        brand_variants=("brand_name", lambda x: sorted(set(x)))
    )
    .reset_index()
)

brand_issue = brand_issue[brand_issue["variant_count"] > 1]

brand_issue
# Out:
#           brand_norm  variant_count                             brand_variants
# 47             aplus              2                            [A+Plus, Aplus]
# 143             bonn              2                               [Bonn, bonn]
# 209       cocacolaus              2               [Coca-Cola US, Coca-cola US]
# 265         delichic              2                      [Deli Chic, Delichic]
# 510       kharifoods              2                 [KHARI FOODS, Khari Foods]
# 704             noto              2                               [NOTO, Noto]
# 767        patanjali              2                     [PATANJALI, Patanjali]
# 793  plixtheplantfix              2  [Plix -The Plant Fix, Plix The Plant Fix]

# %%
df[df["brand_norm"] == "aplus"][
    [
        "brand_name",
        "product_name",
        "unique_id",
        "product_id_upc_ean",
        "product_url"
    ]
].sort_values(["product_name", "brand_name"])
# Out:
#       brand_name                product_name  \
# 81062     A+Plus     A+PLUS Kabuli Chana Big
# 81065     A+Plus  A+PLUS Kabuli Chana Medium
# 81061     A+Plus   A+PLUS Moong Dal | Chilka
# 81064     A+Plus          A+PLUS Moong Sabut
# 81072     A+Plus        A+PLUS Rajmah Chitra
# 81074     A+Plus           A+PLUS Rajmah Red
# 81055      Aplus              A+PLUS Tur Dal
# 81068     A+Plus           A+PLUS Urad Sabut
#
#                                   unique_id  \
# 81062  78180479-3b97-493a-9e34-05d1924b5743
# 81065  2fa76236-1adc-451b-9c26-b6f00b88cba9
# 81061  413a8369-5433-425a-b845-2a3c2f0a1e3c
# 81064  c816452b-4063-470b-8c47-7cbd729a418d
# 81072  215989f7-c909-4d84-a262-debb0082d6e2
# 81074  03f68c3b-edb5-4807-a9bf-78ce5f166e5e
# 81055  73738e7b-cb4f-4613-b4ec-2ab6cc61e234
# 81068  1db2af85-177a-4984-9924-3e308c32ec2b
#
#                          product_id_upc_ean  \
# 81062  57d94087-5da9-482b-8866-95e24fdbc640
# 81065  8f1642f3-c542-4966-9617-7ac4179106dd
# 81061  8d7e318f-3704-4085-afb2-4c279ef8983f
# 81064  9de583fd-7670-4d8e-98f4-586be285104b
# 81072  464fc58c-1467-43d3-a91a-75984341fc43
# 81074  0e5130c5-caa8-44ea-8a63-5aeea7398b84
# 81055  e494c824-1685-42b7-9482-dae51f64ee4d
# 81068  137f4c7b-2f23-441e-8583-27bd8baeeda7
#
#                                                                                         product_url
# 81062     https://www.zepto.com/pn/aplus-kabuli-chana-big/pvid/78180479-3b97-493a-9e34-05d1924b5743
# 81065  https://www.zepto.com/pn/aplus-kabuli-chana-medium/pvid/2fa76236-1adc-451b-9c26-b6f00b88cba9
# 81061     https://www.zepto.com/pn/aplus-moong-dal-chilka/pvid/413a8369-5433-425a-b845-2a3c2f0a1e3c
# 81064          https://www.zepto.com/pn/aplus-moong-sabut/pvid/c816452b-4063-470b-8c47-7cbd729a418d
# 81072        https://www.zepto.com/pn/aplus-rajmah-chitra/pvid/215989f7-c909-4d84-a262-debb0082d6e2
# 81074           https://www.zepto.com/pn/aplus-rajmah-red/pvid/03f68c3b-edb5-4807-a9bf-78ce5f166e5e
# 81055              https://www.zepto.com/pn/aplus-tur-dal/pvid/73738e7b-cb4f-4613-b4ec-2ab6cc61e234
# 81068           https://www.zepto.com/pn/aplus-urad-sabut/pvid/1db2af85-177a-4984-9924-3e308c32ec2b

# %%
url_name_issues = (
    df.groupby("product_id_upc_ean")
      .agg(
          product_count=("product_name", "nunique"),
          product_names=("product_name", lambda x: sorted(set(x)))
      )
      .reset_index()
)

url_name_issues = url_name_issues[url_name_issues["product_count"] > 1]

print("URLs with different product names:", len(url_name_issues))
url_name_issues.head()
# Out:
# URLs with different product names: 1
#                         product_id_upc_ean  product_count  \
# 6971  fcd3ccb2-4d6f-49b9-a5ad-c584e474213c              2
#
#                                                                                  product_names
# 6971  [Orbit Spearmint Sugar Free Chewing Gum Tube, Orbit Spearmint Sugarfree Chewing Gum Pot]

# %%
df.columns
# Out:
# Index(['crawl_date_and_time', 'platform_name', 'store_id',
#        'store_name_location', 'city', 'pin_code', 'unique_id',
#        'product_id_upc_ean', 'department', 'category', 'sub_category',
#        'product_type', 'brand_name', 'product_name', 'product_description',
#        'product_grammage', 'package_type', 'net_quantity', 'variants',
#        'item_mrp', 'item_selling_price', 'out_of_stock_flag', 'discount_flag',
#        'product_price', 'unit_price', 'promo_offer_description',
#        'promo_offer_price', 'discount_in_percent', 'stock_count',
#        'product_url', 'product_image_urls'],
#       dtype='object')

# %%
result = (
    df.groupby("product_url")
      .agg(
          product_count=("product_name", "nunique"),
          product_names=("product_name", lambda x: sorted(set(x))),
          unique_ids=("unique_id", lambda x: sorted(set(x))),
          product_ids=("product_id_upc_ean", lambda x: sorted(set(x)))
      )
      .reset_index()
)

# Keep only URLs mapped to multiple product names
result = result[result["product_count"] > 1]

print(f"Found {len(result)} URLs with different product names.")
result
# Out:
# Found 0 URLs with different product names.
# Empty DataFrame
# Columns: [product_url, product_count, product_names, unique_ids, product_ids]
# Index: []

# %%
top10_longest = (
    df.drop_duplicates(subset="product_name")
      .assign(name_length=lambda x: x["product_name"].fillna("").str.len())
      .sort_values("name_length", ascending=False)
      [["unique_id", "name_length", "product_name", "product_url"]]
      .head(10)
)

print(top10_longest)
# Out:
#                                    unique_id  name_length  \
# 93314   7e1c699f-d191-4be4-9314-3506b1a75b97          389
# 376457  2bdf7ef7-4796-4969-ba37-5fca1e01b31c          259
# 93311   edd24376-4a56-4c30-bc25-17740efa5f75          206
# 128053  58caf284-73d7-4a9e-ab54-eb51f6b197f5          204
# 92684   7cfc3765-fcc7-41e0-8a86-f39bd0c19271          186
# 19783   05099171-d97f-4169-99d8-2f6fc01a0c22          170
    df.groupby(["unique_id", "product_grammage", "net_quantity"])
    .agg(
        # Count how many different spelling/name variations exist for this product
        name_variant_count=("product_name", "nunique"),
        # Create an alphabetised list of those unique name variations
        name_variants=("product_name", lambda x: sorted(set(x))),
        # Optional: capture variations in brand name for the same product
        brand_variants=("brand_name", lambda x: sorted(set(x.dropna()))),
    )
    .reset_index()
)

# 2. Filter for rows where the same product has more than 1 name variation
name_issues_by_id = product_identity_issues[
    product_identity_issues["name_variant_count"] > 1
]

# 3. View the final flagged discrepancies
print(name_issues_by_id)
# Out:
#                                  unique_id product_grammage     net_quantity  \
# 1758  51e330d7-1483-4cd3-80d0-ff29eba1b153           59.4 g  1 pack (59.4 g)
# 2114  61b8e3c5-b1b7-4b71-bb21-3a4f1c2ec1a8           19.8 g  1 pack (19.8 g)
#
#       name_variant_count  \
# 1758                   2
# 2114                   2
#
#                                                                                  name_variants  \
# 1758  [Orbit Spearmint Sugar Free Chewing Gum Tube, Orbit Spearmint Sugarfree Chewing Gum Pot]
# 2114  [Orbit Spearmint Sugar Free Chewing Gum Tube, Orbit Spearmint Sugarfree Chewing Gum Pot]
#
#      brand_variants
# 1758        [Orbit]
# 2114        [Orbit]

# %%
product_identity_issues = (
    df.groupby(["unique_id", "product_grammage", "net_quantity"])
    .agg(
        name_variant_count=("product_name", "nunique"),
        name_variants=("product_name", lambda x: sorted(set(x))),
        brand_variants=("brand_name", lambda x: sorted(set(x.dropna()))),
        url_count=("product_url", "nunique"),
        product_urls=("product_url", lambda x: sorted(set(x.dropna())))
    )
    .reset_index()
)

name_issues_by_id = product_identity_issues[
    product_identity_issues["name_variant_count"] > 1
]

name_issues_by_id
# Out:
#                                  unique_id product_grammage     net_quantity  \
# 1758  51e330d7-1483-4cd3-80d0-ff29eba1b153           59.4 g  1 pack (59.4 g)
# 2114  61b8e3c5-b1b7-4b71-bb21-3a4f1c2ec1a8           19.8 g  1 pack (19.8 g)
#
#       name_variant_count  \
# 1758                   2
# 2114                   2
#
#                                                                                  name_variants  \
# 1758  [Orbit Spearmint Sugar Free Chewing Gum Tube, Orbit Spearmint Sugarfree Chewing Gum Pot]
# 2114  [Orbit Spearmint Sugar Free Chewing Gum Tube, Orbit Spearmint Sugarfree Chewing Gum Pot]
#
#      brand_variants  url_count  \
# 1758        [Orbit]          2
# 2114        [Orbit]          2
#
#                                                                                                                                                                                                                         product_urls
# 1758  [https://www.zepto.com/pn/orbit-spearmint-sugar-free-chewing-gum-tube/pvid/51e330d7-1483-4cd3-80d0-ff29eba1b153, https://www.zepto.com/pn/orbit-spearmint-sugarfree-chewing-gum-pot/pvid/51e330d7-1483-4cd3-80d0-ff29eba1b153]
# 2114  [https://www.zepto.com/pn/orbit-spearmint-sugar-free-chewing-gum-tube/pvid/61b8e3c5-b1b7-4b71-bb21-3a4f1c2ec1a8, https://www.zepto.com/pn/orbit-spearmint-sugarfree-chewing-gum-pot/pvid/61b8e3c5-b1b7-4b71-bb21-3a4f1c2ec1a8]
