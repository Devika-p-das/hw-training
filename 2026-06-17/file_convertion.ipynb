# %%
import pandas as pd

# %%
df = pd.read_parquet(r"/home/user/Downloads/swiggy_instamart_2026_06_16.parquet")

# %%
df.head()
# Out:
#    crawl_date_and_time     platform_name  store_id  store_name_location  city  \
# 0  2026-06-13 13:13:16  swiggy instamart   1386719                  NaN   NaN
# 1  2026-06-13 13:13:16  swiggy instamart   1386719                  NaN   NaN
# 2  2026-06-13 13:13:16  swiggy instamart   1386719                  NaN   NaN
# 3  2026-06-13 13:13:16  swiggy instamart   1386719                  NaN   NaN
# 4  2026-06-13 13:13:16  swiggy instamart   1386719                  NaN   NaN
#
#    pin_code   unique_id product_id_upc_ean  department            category  \
# 0    110006  JJPBU6882K         9MWP13YQKE         NaN  Atta, Rice and Dal
# 1    110006  DIQNWDNUNH         BI8M5ZXAW9         NaN  Atta, Rice and Dal
# 2    110006  K79TNFTLWJ         X9SQLG6CTE         NaN  Atta, Rice and Dal
# 3    110006  RK5XDYXJIX         LHNJ100V83         NaN  Atta, Rice and Dal
# 4    110006  6CJ1V31SSP         7E2FXNPLM2         NaN  Atta, Rice and Dal
#
#    ... out_of_stock_flag  discount_flag product_price unit_price  \
# 0  ...               Yes             No            35        NaN
# 1  ...               Yes            Yes            75        NaN
# 2  ...               Yes            Yes            95        NaN
# 3  ...               Yes            Yes           117        NaN
# 4  ...               Yes            Yes            85        NaN
#
#    promo_offer_description promo_offer_price  discount_in_percent  \
# 0                 No offer                35                    0
# 1                  49% OFF                75                   49
# 2                   5% OFF                95                    5
# 3                  21% OFF               117                   21
# 4                  42% OFF                85                   42
#
#    stock_count                                       product_url  \
# 0            8  https://www.swiggy.com/instamart/item/9MWP13YQKE
# 1            1  https://www.swiggy.com/instamart/item/BI8M5ZXAW9
# 2            1  https://www.swiggy.com/instamart/item/X9SQLG6CTE
# 3            1  https://www.swiggy.com/instamart/item/LHNJ100V83
# 4            1  https://www.swiggy.com/instamart/item/7E2FXNPLM2
#
#                                   product_image_urls
# 0  https://instamart-media-assets.swiggy.com/swig...
# 1  https://instamart-media-assets.swiggy.com/swig...
# 2  https://instamart-media-assets.swiggy.com/swig...
# 3  https://instamart-media-assets.swiggy.com/swig...
# 4  https://instamart-media-assets.swiggy.com/swig...
#
# [5 rows x 31 columns]

# %%
df.to_csv("output.csv", index=False)

# %%
# Convert to JSON
json_file = "data.json"
df.to_json(json_file, orient="records", indent=4)

# %%
# Convert to XML
xml_file = "data.xml"
df.to_xml(xml_file, index=False)

# %%
# Convert to Excel
excel_file = "data.xlsx"
df.to_excel(excel_file, index=False)
